# %%
import pandas as pd
import matplotlib.pyplot as plt
import numpy as np

# 1. 创建文件名列表
filenames_01 = [
    # "./Results/2025110_4_No_select_Hart6_UCB_True_20_400_6_CumRegret.csv",
    # "./Results/HCA_v3_4_No_select_Hart6_UCB_True_20_400_6_CumRegret.csv",
    "./Results/HCA_Sample_v318_4_No_select_Branin_UCB_0.1_20_400_2_CumRegret.csv",
    "./Results/HCA_Sample_v318_v2_4_No_select_Branin_UCB_0.1_20_400_2_CumRegret.csv",
    # "./Results/HCA_v5_4_No_select_Hart6_UCB_0.1_20_400_6_CumRegret.csv",
    # "./Results/COCOA_4_No_select_Hart6_UCB_True_20_400_6_CumRegret.csv",
    # "./Results/COCOA_v4_4_No_select_Hart6_UCB_0.1_20_400_6_CumRegret.csv",
    # "./Results/HCA_multi_baseline_v2_4_No_select_Hart6_UCB_0.1_20_400_6_CumRegret.csv",
    "./Results/Baseline_318_4_No_select_Branin_UCB_0.1_20_400_2_CumRegret.csv",
    
    # "./Results/Baseline2_4_No_select_Hart6_UCB_0.1_20_400_6_CumRegret.csv",
    # "./Results/HCA_ini_4_No_select_Hart6_UCB_True_20_400_6_CumRegret.csv",
    # "./Results/COCOA_ini_4_No_select_Hart6_UCB_True_20_400_6_CumRegret.csv",
    # ... 其他文件名
]

# Center_random_2024086_keepinitial_4_Random_select_Hart6_UCB_0.1_20_400_6_Regret.csv

# 定义自定义标签
labels = ['HCA_Sample','HCA_Sample_v2','Standard BO', 'Hart6_UCB_Random_select-4-Center', 'Hart6_UCB_Random_select-4-Weight', 'Hart6_Random_AC_No_select']
colors = ['blue', 'red', 'green', 'orange', 'purple','black']

plt.figure(figsize=(4, 3))

# 2. 对每个文件进行迭代
for idx, file in enumerate(filenames_01):
    # 读取数据
    data = pd.read_csv(file, header=None)
    # 计算平均值和标准差
    averages = data.mean(axis=0)
    std_devs = data.std(axis=0)
    
    # 3. 绘制平均值和误差带
    plt.plot(averages, label=labels[idx], color=colors[idx])
    plt.fill_between(range(len(averages)), averages - std_devs, averages + std_devs, color=colors[idx], alpha=0.2)

plt.title("CumRegret")
plt.xlabel("Index")
plt.ylabel("Average Value")
plt.legend()
plt.grid(True)
plt.show()

# %%
import pandas as pd
import matplotlib.pyplot as plt
import numpy as np

# 1. 创建文件名列表
filenames_01 = [
    # "./Results/2025110_4_No_select_Hart6_UCB_True_20_400_6_CumRegret.csv",
    # "./Results/HCA_v3_4_No_select_Hart6_UCB_True_20_400_6_CumRegret.csv",
    "./Results/HCA_Sample_v318_4_No_select_Branin_EI_0.1_20_400_2_CumRegret.csv",
    # "./Results/HCA_v5_4_No_select_Hart6_UCB_0.1_20_400_6_CumRegret.csv",
    # "./Results/COCOA_4_No_select_Hart6_UCB_True_20_400_6_CumRegret.csv",
    # "./Results/COCOA_v4_4_No_select_Hart6_UCB_0.1_20_400_6_CumRegret.csv",
    # "./Results/HCA_multi_baseline_v2_4_No_select_Hart6_UCB_0.1_20_400_6_CumRegret.csv",
    "./Results/Baseline_318_4_No_select_Branin_EI_0.1_20_400_2_CumRegret.csv",
    # "./Results/HCA_Sample_v318_v2_4_No_select_Branin_EI_0.1_20_400_2_CumRegret.csv",
    # "./Results/Baseline2_4_No_select_Hart6_UCB_0.1_20_400_6_CumRegret.csv",
    # "./Results/HCA_ini_4_No_select_Hart6_UCB_True_20_400_6_CumRegret.csv",
    # "./Results/COCOA_ini_4_No_select_Hart6_UCB_True_20_400_6_CumRegret.csv",
    # ... 其他文件名
]

# Center_random_2024086_keepinitial_4_Random_select_Hart6_UCB_0.1_20_400_6_Regret.csv

# 定义自定义标签
labels = ['HCA','Standard BO', 'Hart6_UCB_Random_select-4-Center', 'Hart6_UCB_Random_select-4-Weight', 'Hart6_Random_AC_No_select']
colors = ['blue', 'red', 'green', 'orange', 'purple','black']

plt.figure(figsize=(4, 3))

# 2. 对每个文件进行迭代
for idx, file in enumerate(filenames_01):
    # 读取数据
    data = pd.read_csv(file, header=None)
    # 计算平均值和标准差
    averages = data.mean(axis=0)
    std_devs = data.std(axis=0)
    
    # 3. 绘制平均值和误差带
    plt.plot(averages, label=labels[idx], color=colors[idx])
    plt.fill_between(range(len(averages)), averages - std_devs, averages + std_devs, color=colors[idx], alpha=0.2)

plt.title("CumRegret")
plt.xlabel("Index")
plt.ylabel("Average Value")
plt.legend()
plt.grid(True)
plt.show()

# %%
import pandas as pd
import matplotlib.pyplot as plt
import numpy as np

# 1. 创建文件名列表
filenames_01 = [
    # "./Results/2025110_4_No_select_Hart6_UCB_True_20_400_6_CumRegret.csv",
    # "./Results/HCA_v3_4_No_select_Hart6_UCB_True_20_400_6_CumRegret.csv",
    "./Results/HCA_Sample_v318_4_No_select_Branin_TS_0.1_20_400_2_CumRegret.csv",
    "./Results/HCA_Sample_v318_v2_4_No_select_Branin_TS_0.1_20_400_2_CumRegret.csv",
    # "./Results/HCA_v5_4_No_select_Hart6_UCB_0.1_20_400_6_CumRegret.csv",
    # "./Results/COCOA_4_No_select_Hart6_UCB_True_20_400_6_CumRegret.csv",
    # "./Results/COCOA_v4_4_No_select_Hart6_UCB_0.1_20_400_6_CumRegret.csv",
    # "./Results/HCA_multi_baseline_v2_4_No_select_Hart6_UCB_0.1_20_400_6_CumRegret.csv",
    "./Results/Baseline_318_4_No_select_Branin_TS_0.1_20_400_2_CumRegret.csv",
    # "./Results/Baseline2_4_No_select_Hart6_UCB_0.1_20_400_6_CumRegret.csv",
    # "./Results/HCA_ini_4_No_select_Hart6_UCB_True_20_400_6_CumRegret.csv",
    # "./Results/COCOA_ini_4_No_select_Hart6_UCB_True_20_400_6_CumRegret.csv",
    # ... 其他文件名
]

# Center_random_2024086_keepinitial_4_Random_select_Hart6_UCB_0.1_20_400_6_Regret.csv

# 定义自定义标签
labels = ['HCA_Sample','HCA_Sample_v2','Standard BO', 'Hart6_UCB_Random_select-4-Center', 'Hart6_UCB_Random_select-4-Weight', 'Hart6_Random_AC_No_select']
colors = ['blue', 'red', 'green', 'orange', 'purple','black']

plt.figure(figsize=(4, 3))

# 2. 对每个文件进行迭代
for idx, file in enumerate(filenames_01):
    # 读取数据
    data = pd.read_csv(file, header=None)
    # 计算平均值和标准差
    averages = data.mean(axis=0)
    std_devs = data.std(axis=0)
    
    # 3. 绘制平均值和误差带
    plt.plot(averages, label=labels[idx], color=colors[idx])
    plt.fill_between(range(len(averages)), averages - std_devs, averages + std_devs, color=colors[idx], alpha=0.2)

plt.title("CumRegret")
plt.xlabel("Index")
plt.ylabel("Average Value")
plt.legend()
plt.grid(True)
plt.show()

# %%
import pandas as pd
import matplotlib.pyplot as plt
import numpy as np

# 1. 创建文件名列表
filenames_01 = [
    # "./Results/2025110_4_No_select_Hart6_UCB_True_20_400_6_CumRegret.csv",
    # "./Results/HCA_v3_4_No_select_Hart6_UCB_True_20_400_6_CumRegret.csv",
    "./Results/HCA_Sample_v318_4_No_select_Hart6_UCB_0.1_20_400_6_CumRegret.csv",
    "./Results/HCA_Sample_v318_v2_4_No_select_Hart6_UCB_0.1_20_400_6_CumRegret.csv",
    # "./Results/HCA_v5_4_No_select_Hart6_UCB_0.1_20_400_6_CumRegret.csv",
    # "./Results/COCOA_4_No_select_Hart6_UCB_True_20_400_6_CumRegret.csv",
    # "./Results/COCOA_v4_4_No_select_Hart6_UCB_0.1_20_400_6_CumRegret.csv",
    # "./Results/HCA_multi_baseline_v2_4_No_select_Hart6_UCB_0.1_20_400_6_CumRegret.csv",
    "./Results/Baseline_318_4_No_select_Hart6_UCB_0.1_20_400_6_CumRegret.csv",
    # "./Results/HCA_Sample_v318_v2_4_No_select_Hart6_UCB_0.1_20_400_6_CumRegret.csv",
    # "./Results/Baseline2_4_No_select_Hart6_UCB_0.1_20_400_6_CumRegret.csv",
    # "./Results/HCA_ini_4_No_select_Hart6_UCB_True_20_400_6_CumRegret.csv",
    # "./Results/COCOA_ini_4_No_select_Hart6_UCB_True_20_400_6_CumRegret.csv",
    # ... 其他文件名
]

# Center_random_2024086_keepinitial_4_Random_select_Hart6_UCB_0.1_20_400_6_Regret.csv

# 定义自定义标签
labels = ['HCA_Sample','HCA_Sample_v2','Standard BO', 'Hart6_UCB_Random_select-4-Center', 'Hart6_UCB_Random_select-4-Weight', 'Hart6_Random_AC_No_select']
colors = ['blue', 'red', 'green', 'orange', 'purple','black']

plt.figure(figsize=(4, 3))

# 2. 对每个文件进行迭代
for idx, file in enumerate(filenames_01):
    # 读取数据
    data = pd.read_csv(file, header=None)
    # 计算平均值和标准差
    averages = data.mean(axis=0)
    std_devs = data.std(axis=0)
    
    # 3. 绘制平均值和误差带
    plt.plot(averages, label=labels[idx], color=colors[idx])
    plt.fill_between(range(len(averages)), averages - std_devs, averages + std_devs, color=colors[idx], alpha=0.2)

plt.title("CumRegret")
plt.xlabel("Index")
plt.ylabel("Average Value")
plt.legend()
plt.grid(True)
plt.show()

# %%
import pandas as pd
import matplotlib.pyplot as plt
import numpy as np

# 1. 创建文件名列表
filenames_01 = [
    # "./Results/2025110_4_No_select_Hart6_UCB_True_20_400_6_CumRegret.csv",
    # "./Results/HCA_v3_4_No_select_Hart6_UCB_True_20_400_6_CumRegret.csv",
    "./Results/HCA_Sample_v318_4_No_select_Hart6_EI_0.1_20_400_6_CumRegret.csv",
    # "./Results/HCA_v5_4_No_select_Hart6_UCB_0.1_20_400_6_CumRegret.csv",
    # "./Results/COCOA_4_No_select_Hart6_UCB_True_20_400_6_CumRegret.csv",
    # "./Results/COCOA_v4_4_No_select_Hart6_UCB_0.1_20_400_6_CumRegret.csv",
    # "./Results/HCA_multi_baseline_v2_4_No_select_Hart6_UCB_0.1_20_400_6_CumRegret.csv",
    "./Results/Baseline_318_4_No_select_Hart6_EI_0.1_20_400_6_CumRegret.csv",
    "./Results/HCA_Sample_v318_v2_4_No_select_Hart6_EI_0.1_20_400_6_CumRegret.csv",
    # "./Results/Baseline2_4_No_select_Hart6_UCB_0.1_20_400_6_CumRegret.csv",
    # "./Results/HCA_ini_4_No_select_Hart6_UCB_True_20_400_6_CumRegret.csv",
    # "./Results/COCOA_ini_4_No_select_Hart6_UCB_True_20_400_6_CumRegret.csv",
    # ... 其他文件名
]

# Center_random_2024086_keepinitial_4_Random_select_Hart6_UCB_0.1_20_400_6_Regret.csv

# 定义自定义标签
labels = ['HCA','Standard BO', 'Hart6_UCB_Random_select-4-Center', 'Hart6_UCB_Random_select-4-Weight', 'Hart6_Random_AC_No_select']
colors = ['blue', 'red', 'green', 'orange', 'purple','black']

plt.figure(figsize=(4, 3))

# 2. 对每个文件进行迭代
for idx, file in enumerate(filenames_01):
    # 读取数据
    data = pd.read_csv(file, header=None)
    # 计算平均值和标准差
    averages = data.mean(axis=0)
    std_devs = data.std(axis=0)
    
    # 3. 绘制平均值和误差带
    plt.plot(averages, label=labels[idx], color=colors[idx])
    plt.fill_between(range(len(averages)), averages - std_devs, averages + std_devs, color=colors[idx], alpha=0.2)

plt.title("CumRegret")
plt.xlabel("Index")
plt.ylabel("Average Value")
plt.legend()
plt.grid(True)
plt.show()

# %%
import pandas as pd
import matplotlib.pyplot as plt
import numpy as np

# 1. 创建文件名列表
filenames_01 = [
    # "./Results/2025110_4_No_select_Hart6_UCB_True_20_400_6_CumRegret.csv",
    # "./Results/HCA_v3_4_No_select_Hart6_UCB_True_20_400_6_CumRegret.csv",
    "./Results/HCA_Sample_v318_4_No_select_Hart6_TS_0.1_20_400_6_CumRegret.csv",
    # "./Results/HCA_v5_4_No_select_Hart6_UCB_0.1_20_400_6_CumRegret.csv",
    # "./Results/COCOA_4_No_select_Hart6_UCB_True_20_400_6_CumRegret.csv",
    # "./Results/COCOA_v4_4_No_select_Hart6_UCB_0.1_20_400_6_CumRegret.csv",
    # "./Results/HCA_multi_baseline_v2_4_No_select_Hart6_UCB_0.1_20_400_6_CumRegret.csv",
    "./Results/Baseline_318_4_No_select_Hart6_TS_0.1_20_400_6_CumRegret.csv",
    # "./Results/Baseline2_4_No_select_Hart6_UCB_0.1_20_400_6_CumRegret.csv",
    # "./Results/HCA_ini_4_No_select_Hart6_UCB_True_20_400_6_CumRegret.csv",
    # "./Results/COCOA_ini_4_No_select_Hart6_UCB_True_20_400_6_CumRegret.csv",
    # ... 其他文件名
]

# Center_random_2024086_keepinitial_4_Random_select_Hart6_UCB_0.1_20_400_6_Regret.csv

# 定义自定义标签
labels = ['HCA','Standard BO', 'Hart6_UCB_Random_select-4-Center', 'Hart6_UCB_Random_select-4-Weight', 'Hart6_Random_AC_No_select']
colors = ['blue', 'red', 'green', 'orange', 'purple','black']

plt.figure(figsize=(4, 3))

# 2. 对每个文件进行迭代
for idx, file in enumerate(filenames_01):
    # 读取数据
    data = pd.read_csv(file, header=None)
    # 计算平均值和标准差
    averages = data.mean(axis=0)
    std_devs = data.std(axis=0)
    
    # 3. 绘制平均值和误差带
    plt.plot(averages, label=labels[idx], color=colors[idx])
    plt.fill_between(range(len(averages)), averages - std_devs, averages + std_devs, color=colors[idx], alpha=0.2)

plt.title("CumRegret")
plt.xlabel("Index")
plt.ylabel("Average Value")
plt.legend()
plt.grid(True)
plt.show()

# %%
import pandas as pd
import matplotlib.pyplot as plt
import numpy as np

# 1. 创建文件名列表
filenames_01 = [
    # "./Results/2025110_4_No_select_Hart6_UCB_True_20_400_6_CumRegret.csv",
    # "./Results/HCA_v3_4_No_select_Hart6_UCB_True_20_400_6_CumRegret.csv",
    "./Results/HCA_Sample_v318_4_No_select_Levy_UCB_0.1_20_400_20_CumRegret.csv",
    # "./Results/HCA_v5_4_No_select_Hart6_UCB_0.1_20_400_6_CumRegret.csv",
    # "./Results/COCOA_4_No_select_Hart6_UCB_True_20_400_6_CumRegret.csv",
    # "./Results/COCOA_v4_4_No_select_Hart6_UCB_0.1_20_400_6_CumRegret.csv",
    # "./Results/HCA_multi_baseline_v2_4_No_select_Hart6_UCB_0.1_20_400_6_CumRegret.csv",
    "./Results/Baseline_318_4_No_select_Levy_UCB_0.1_20_400_20_CumRegret.csv",
    # "./Results/Baseline2_4_No_select_Hart6_UCB_0.1_20_400_6_CumRegret.csv",
    # "./Results/HCA_ini_4_No_select_Hart6_UCB_True_20_400_6_CumRegret.csv",
    # "./Results/COCOA_ini_4_No_select_Hart6_UCB_True_20_400_6_CumRegret.csv",
    # ... 其他文件名
]

# Center_random_2024086_keepinitial_4_Random_select_Hart6_UCB_0.1_20_400_6_Regret.csv

# 定义自定义标签
labels = ['HCA','Standard BO', 'Hart6_UCB_Random_select-4-Center', 'Hart6_UCB_Random_select-4-Weight', 'Hart6_Random_AC_No_select']
colors = ['blue', 'red', 'green', 'orange', 'purple','black']

plt.figure(figsize=(4, 3))

# 2. 对每个文件进行迭代
for idx, file in enumerate(filenames_01):
    # 读取数据
    data = pd.read_csv(file, header=None)
    # 计算平均值和标准差
    averages = data.mean(axis=0)
    std_devs = data.std(axis=0)
    
    # 3. 绘制平均值和误差带
    plt.plot(averages, label=labels[idx], color=colors[idx])
    plt.fill_between(range(len(averages)), averages - std_devs, averages + std_devs, color=colors[idx], alpha=0.2)

plt.title("CumRegret")
plt.xlabel("Index")
plt.ylabel("Average Value")
plt.legend()
plt.grid(True)
plt.show()

# %%
import pandas as pd
import matplotlib.pyplot as plt
import numpy as np

# 1. 创建文件名列表
filenames_01 = [
    # "./Results/2025110_4_No_select_Hart6_UCB_True_20_400_6_CumRegret.csv",
    # "./Results/HCA_v3_4_No_select_Hart6_UCB_True_20_400_6_CumRegret.csv",
    "./Results/HCA_Sample_v318_4_No_select_Levy_EI_0.1_20_400_20_CumRegret.csv",
    # "./Results/HCA_v5_4_No_select_Hart6_UCB_0.1_20_400_6_CumRegret.csv",
    # "./Results/COCOA_4_No_select_Hart6_UCB_True_20_400_6_CumRegret.csv",
    # "./Results/COCOA_v4_4_No_select_Hart6_UCB_0.1_20_400_6_CumRegret.csv",
    # "./Results/HCA_multi_baseline_v2_4_No_select_Hart6_UCB_0.1_20_400_6_CumRegret.csv",
    "./Results/Baseline_318_4_No_select_Levy_EI_0.1_20_400_20_CumRegret.csv",
    # "./Results/Baseline2_4_No_select_Hart6_UCB_0.1_20_400_6_CumRegret.csv",
    # "./Results/HCA_ini_4_No_select_Hart6_UCB_True_20_400_6_CumRegret.csv",
    # "./Results/COCOA_ini_4_No_select_Hart6_UCB_True_20_400_6_CumRegret.csv",
    # ... 其他文件名
]

# Center_random_2024086_keepinitial_4_Random_select_Hart6_UCB_0.1_20_400_6_Regret.csv

# 定义自定义标签
labels = ['HCA','Standard BO', 'Hart6_UCB_Random_select-4-Center', 'Hart6_UCB_Random_select-4-Weight', 'Hart6_Random_AC_No_select']
colors = ['blue', 'red', 'green', 'orange', 'purple','black']

plt.figure(figsize=(4, 3))

# 2. 对每个文件进行迭代
for idx, file in enumerate(filenames_01):
    # 读取数据
    data = pd.read_csv(file, header=None)
    # 计算平均值和标准差
    averages = data.mean(axis=0)
    std_devs = data.std(axis=0)
    
    # 3. 绘制平均值和误差带
    plt.plot(averages, label=labels[idx], color=colors[idx])
    plt.fill_between(range(len(averages)), averages - std_devs, averages + std_devs, color=colors[idx], alpha=0.2)

plt.title("CumRegret")
plt.xlabel("Index")
plt.ylabel("Average Value")
plt.legend()
plt.grid(True)
plt.show()

# %%
import pandas as pd
import matplotlib.pyplot as plt
import numpy as np

# 1. 创建文件名列表
filenames_01 = [
    # "./Results/2025110_4_No_select_Hart6_UCB_True_20_400_6_CumRegret.csv",
    # "./Results/HCA_v3_4_No_select_Hart6_UCB_True_20_400_6_CumRegret.csv",
    "./Results/HCA_Sample_v318_4_No_select_Levy_TS_0.1_20_400_20_CumRegret.csv",
    # "./Results/HCA_v5_4_No_select_Hart6_UCB_0.1_20_400_6_CumRegret.csv",
    # "./Results/COCOA_4_No_select_Hart6_UCB_True_20_400_6_CumRegret.csv",
    # "./Results/COCOA_v4_4_No_select_Hart6_UCB_0.1_20_400_6_CumRegret.csv",
    # "./Results/HCA_multi_baseline_v2_4_No_select_Hart6_UCB_0.1_20_400_6_CumRegret.csv",
    "./Results/Baseline_318_4_No_select_Levy_TS_0.1_20_400_20_CumRegret.csv",
    # "./Results/Baseline2_4_No_select_Hart6_UCB_0.1_20_400_6_CumRegret.csv",
    # "./Results/HCA_ini_4_No_select_Hart6_UCB_True_20_400_6_CumRegret.csv",
    # "./Results/COCOA_ini_4_No_select_Hart6_UCB_True_20_400_6_CumRegret.csv",
    # ... 其他文件名
]

# Center_random_2024086_keepinitial_4_Random_select_Hart6_UCB_0.1_20_400_6_Regret.csv

# 定义自定义标签
labels = ['HCA','Standard BO', 'Hart6_UCB_Random_select-4-Center', 'Hart6_UCB_Random_select-4-Weight', 'Hart6_Random_AC_No_select']
colors = ['blue', 'red', 'green', 'orange', 'purple','black']

plt.figure(figsize=(4, 3))

# 2. 对每个文件进行迭代
for idx, file in enumerate(filenames_01):
    # 读取数据
    data = pd.read_csv(file, header=None)
    # 计算平均值和标准差
    averages = data.mean(axis=0)
    std_devs = data.std(axis=0)
    
    # 3. 绘制平均值和误差带
    plt.plot(averages, label=labels[idx], color=colors[idx])
    plt.fill_between(range(len(averages)), averages - std_devs, averages + std_devs, color=colors[idx], alpha=0.2)

plt.title("CumRegret")
plt.xlabel("Index")
plt.ylabel("Average Value")
plt.legend()
plt.grid(True)
plt.show()

# %%
import pandas as pd
import matplotlib.pyplot as plt
import numpy as np

# 1. 创建文件名列表
filenames_01 = [
    # "./Results/2025110_4_No_select_Hart6_UCB_True_20_400_6_CumRegret.csv",
    # "./Results/HCA_v3_4_No_select_Hart6_UCB_True_20_400_6_CumRegret.csv",
    "./Results/HCA_Sample_v318_4_No_select_Powell_UCB_0.1_20_400_50_CumRegret.csv",
    # "./Results/HCA_v5_4_No_select_Hart6_UCB_0.1_20_400_6_CumRegret.csv",
    # "./Results/COCOA_4_No_select_Hart6_UCB_True_20_400_6_CumRegret.csv",
    # "./Results/COCOA_v4_4_No_select_Hart6_UCB_0.1_20_400_6_CumRegret.csv",
    # "./Results/HCA_multi_baseline_v2_4_No_select_Hart6_UCB_0.1_20_400_6_CumRegret.csv",
    "./Results/Baseline_318_4_No_select_Powell_UCB_0.1_20_400_50_CumRegret.csv",
    # "./Results/Baseline2_4_No_select_Hart6_UCB_0.1_20_400_6_CumRegret.csv",
    # "./Results/HCA_ini_4_No_select_Hart6_UCB_True_20_400_6_CumRegret.csv",
    # "./Results/COCOA_ini_4_No_select_Hart6_UCB_True_20_400_6_CumRegret.csv",
    # ... 其他文件名
]

# Center_random_2024086_keepinitial_4_Random_select_Hart6_UCB_0.1_20_400_6_Regret.csv

# 定义自定义标签
labels = ['HCA','Standard BO', 'Hart6_UCB_Random_select-4-Center', 'Hart6_UCB_Random_select-4-Weight', 'Hart6_Random_AC_No_select']
colors = ['blue', 'red', 'green', 'orange', 'purple','black']

plt.figure(figsize=(4, 3))

# 2. 对每个文件进行迭代
for idx, file in enumerate(filenames_01):
    # 读取数据
    data = pd.read_csv(file, header=None)
    # 计算平均值和标准差
    averages = data.mean(axis=0)
    std_devs = data.std(axis=0)
    
    # 3. 绘制平均值和误差带
    plt.plot(averages, label=labels[idx], color=colors[idx])
    plt.fill_between(range(len(averages)), averages - std_devs, averages + std_devs, color=colors[idx], alpha=0.2)

plt.title("CumRegret")
plt.xlabel("Index")
plt.ylabel("Average Value")
plt.legend()
plt.grid(True)
plt.show()

# %%
import pandas as pd
import matplotlib.pyplot as plt
import numpy as np

# 1. 创建文件名列表
filenames_01 = [
    # "./Results/2025110_4_No_select_Hart6_UCB_True_20_400_6_CumRegret.csv",
    # "./Results/HCA_v3_4_No_select_Hart6_UCB_True_20_400_6_CumRegret.csv",
    "./Results/HCA_KNN_v1_4_No_select_Hart6_UCB_0.1_20_400_6_CumRegret.csv",
    # "./Results/HCA_v5_4_No_select_Hart6_UCB_0.1_20_400_6_CumRegret.csv",
    # "./Results/COCOA_4_No_select_Hart6_UCB_True_20_400_6_CumRegret.csv",
    # "./Results/COCOA_v4_4_No_select_Hart6_UCB_0.1_20_400_6_CumRegret.csv",
    # "./Results/HCA_multi_baseline_v2_4_No_select_Hart6_UCB_0.1_20_400_6_CumRegret.csv",
    "./Results/Baseline_318_4_No_select_Hart6_UCB_0.1_20_400_6_CumRegret.csv",
    # "./Results/Baseline2_4_No_select_Hart6_UCB_0.1_20_400_6_CumRegret.csv",
    # "./Results/HCA_ini_4_No_select_Hart6_UCB_True_20_400_6_CumRegret.csv",
    # "./Results/COCOA_ini_4_No_select_Hart6_UCB_True_20_400_6_CumRegret.csv",
    # ... 其他文件名
]

# Center_random_2024086_keepinitial_4_Random_select_Hart6_UCB_0.1_20_400_6_Regret.csv

# 定义自定义标签
labels = ['HCA','Standard BO', 'Hart6_UCB_Random_select-4-Center', 'Hart6_UCB_Random_select-4-Weight', 'Hart6_Random_AC_No_select']
colors = ['blue', 'red', 'green', 'orange', 'purple','black']

plt.figure(figsize=(4, 3))

# 2. 对每个文件进行迭代
for idx, file in enumerate(filenames_01):
    # 读取数据
    data = pd.read_csv(file, header=None)
    # 计算平均值和标准差
    averages = data.mean(axis=0)
    std_devs = data.std(axis=0)
    
    # 3. 绘制平均值和误差带
    plt.plot(averages, label=labels[idx], color=colors[idx])
    plt.fill_between(range(len(averages)), averages - std_devs, averages + std_devs, color=colors[idx], alpha=0.2)

plt.title("CumRegret")
plt.xlabel("Index")
plt.ylabel("Average Value")
plt.legend()
plt.grid(True)
plt.show()

# %%
import pandas as pd
import matplotlib.pyplot as plt
import numpy as np

# 1. 创建文件名列表
filenames_01 = [
    # "./Results/2025110_4_No_select_Hart6_UCB_True_20_400_6_CumRegret.csv",
    # "./Results/HCA_v3_4_No_select_Hart6_UCB_True_20_400_6_CumRegret.csv",
    "./Results/HCA_KNN_v1_4_No_select_Hart6_EI_0.1_20_400_6_CumRegret.csv",
    # "./Results/HCA_v5_4_No_select_Hart6_UCB_0.1_20_400_6_CumRegret.csv",
    # "./Results/COCOA_4_No_select_Hart6_UCB_True_20_400_6_CumRegret.csv",
    # "./Results/COCOA_v4_4_No_select_Hart6_UCB_0.1_20_400_6_CumRegret.csv",
    # "./Results/HCA_multi_baseline_v2_4_No_select_Hart6_UCB_0.1_20_400_6_CumRegret.csv",
    "./Results/Baseline_318_4_No_select_Hart6_EI_0.1_20_400_6_CumRegret.csv",
    # "./Results/Baseline2_4_No_select_Hart6_UCB_0.1_20_400_6_CumRegret.csv",
    # "./Results/HCA_ini_4_No_select_Hart6_UCB_True_20_400_6_CumRegret.csv",
    # "./Results/COCOA_ini_4_No_select_Hart6_UCB_True_20_400_6_CumRegret.csv",
    # ... 其他文件名
]

# Center_random_2024086_keepinitial_4_Random_select_Hart6_UCB_0.1_20_400_6_Regret.csv

# 定义自定义标签
labels = ['HCA','Standard BO', 'Hart6_UCB_Random_select-4-Center', 'Hart6_UCB_Random_select-4-Weight', 'Hart6_Random_AC_No_select']
colors = ['blue', 'red', 'green', 'orange', 'purple','black']

plt.figure(figsize=(4, 3))

# 2. 对每个文件进行迭代
for idx, file in enumerate(filenames_01):
    # 读取数据
    data = pd.read_csv(file, header=None)
    # 计算平均值和标准差
    averages = data.mean(axis=0)
    std_devs = data.std(axis=0)
    
    # 3. 绘制平均值和误差带
    plt.plot(averages, label=labels[idx], color=colors[idx])
    plt.fill_between(range(len(averages)), averages - std_devs, averages + std_devs, color=colors[idx], alpha=0.2)

plt.title("CumRegret")
plt.xlabel("Index")
plt.ylabel("Average Value")
plt.legend()
plt.grid(True)
plt.show()

# %%
import pandas as pd
import matplotlib.pyplot as plt
import numpy as np

# 1. 创建文件名列表
filenames_01 = [
    # "./Results/2025110_4_No_select_Hart6_UCB_True_20_400_6_CumRegret.csv",
    # "./Results/HCA_v3_4_No_select_Hart6_UCB_True_20_400_6_CumRegret.csv",
    "./Results/HCA_KNN_v1_4_No_select_Hart6_TS_0.1_20_400_6_CumRegret.csv",
    # "./Results/HCA_v5_4_No_select_Hart6_UCB_0.1_20_400_6_CumRegret.csv",
    # "./Results/COCOA_4_No_select_Hart6_UCB_True_20_400_6_CumRegret.csv",
    # "./Results/COCOA_v4_4_No_select_Hart6_UCB_0.1_20_400_6_CumRegret.csv",
    # "./Results/HCA_multi_baseline_v2_4_No_select_Hart6_UCB_0.1_20_400_6_CumRegret.csv",
    "./Results/Baseline_318_4_No_select_Hart6_TS_0.1_20_400_6_CumRegret.csv",
    # "./Results/Baseline2_4_No_select_Hart6_UCB_0.1_20_400_6_CumRegret.csv",
    # "./Results/HCA_ini_4_No_select_Hart6_UCB_True_20_400_6_CumRegret.csv",
    # "./Results/COCOA_ini_4_No_select_Hart6_UCB_True_20_400_6_CumRegret.csv",
    # ... 其他文件名
]

# Center_random_2024086_keepinitial_4_Random_select_Hart6_UCB_0.1_20_400_6_Regret.csv

# 定义自定义标签
labels = ['HCA','Standard BO', 'Hart6_UCB_Random_select-4-Center', 'Hart6_UCB_Random_select-4-Weight', 'Hart6_Random_AC_No_select']
colors = ['blue', 'red', 'green', 'orange', 'purple','black']

plt.figure(figsize=(4, 3))

# 2. 对每个文件进行迭代
for idx, file in enumerate(filenames_01):
    # 读取数据
    data = pd.read_csv(file, header=None)
    # 计算平均值和标准差
    averages = data.mean(axis=0)
    std_devs = data.std(axis=0)
    
    # 3. 绘制平均值和误差带
    plt.plot(averages, label=labels[idx], color=colors[idx])
    plt.fill_between(range(len(averages)), averages - std_devs, averages + std_devs, color=colors[idx], alpha=0.2)

plt.title("CumRegret")
plt.xlabel("Index")
plt.ylabel("Average Value")
plt.legend()
plt.grid(True)
plt.show()

# %%
import pandas as pd
import matplotlib.pyplot as plt
import numpy as np

# 1. 创建文件名列表
filenames_01 = [
    # "./Results/2025110_4_No_select_Hart6_UCB_True_20_400_6_CumRegret.csv",
    # "./Results/HCA_v3_4_No_select_Hart6_UCB_True_20_400_6_CumRegret.csv",
    "./Results/HCA_KNN_v1_4_No_select_Levy_UCB_0.1_20_400_20_CumRegret.csv",
    # "./Results/HCA_v5_4_No_select_Hart6_UCB_0.1_20_400_6_CumRegret.csv",
    # "./Results/COCOA_4_No_select_Hart6_UCB_True_20_400_6_CumRegret.csv",
    # "./Results/COCOA_v4_4_No_select_Hart6_UCB_0.1_20_400_6_CumRegret.csv",
    # "./Results/HCA_multi_baseline_v2_4_No_select_Hart6_UCB_0.1_20_400_6_CumRegret.csv",
    "./Results/Baseline_318_4_No_select_Levy_UCB_0.1_20_400_20_CumRegret.csv",
    # "./Results/Baseline2_4_No_select_Hart6_UCB_0.1_20_400_6_CumRegret.csv",
    # "./Results/HCA_ini_4_No_select_Hart6_UCB_True_20_400_6_CumRegret.csv",
    # "./Results/COCOA_ini_4_No_select_Hart6_UCB_True_20_400_6_CumRegret.csv",
    # ... 其他文件名
]

# Center_random_2024086_keepinitial_4_Random_select_Hart6_UCB_0.1_20_400_6_Regret.csv

# 定义自定义标签
labels = ['HCA','Standard BO', 'Hart6_UCB_Random_select-4-Center', 'Hart6_UCB_Random_select-4-Weight', 'Hart6_Random_AC_No_select']
colors = ['blue', 'red', 'green', 'orange', 'purple','black']

plt.figure(figsize=(4, 3))

# 2. 对每个文件进行迭代
for idx, file in enumerate(filenames_01):
    # 读取数据
    data = pd.read_csv(file, header=None)
    # 计算平均值和标准差
    averages = data.mean(axis=0)
    std_devs = data.std(axis=0)
    
    # 3. 绘制平均值和误差带
    plt.plot(averages, label=labels[idx], color=colors[idx])
    plt.fill_between(range(len(averages)), averages - std_devs, averages + std_devs, color=colors[idx], alpha=0.2)

plt.title("CumRegret")
plt.xlabel("Index")
plt.ylabel("Average Value")
plt.legend()
plt.grid(True)
plt.show()

# %%
import pandas as pd
import matplotlib.pyplot as plt
import numpy as np

# 1. 创建文件名列表
filenames_01 = [
    # "./Results/2025110_4_No_select_Hart6_UCB_True_20_400_6_CumRegret.csv",
    # "./Results/HCA_v3_4_No_select_Hart6_UCB_True_20_400_6_CumRegret.csv",
    "./Results/HCA_KNN_v1_4_No_select_Levy_EI_0.1_20_400_20_CumRegret.csv",
    # "./Results/HCA_v5_4_No_select_Hart6_UCB_0.1_20_400_6_CumRegret.csv",
    # "./Results/COCOA_4_No_select_Hart6_UCB_True_20_400_6_CumRegret.csv",
    # "./Results/COCOA_v4_4_No_select_Hart6_UCB_0.1_20_400_6_CumRegret.csv",
    # "./Results/HCA_multi_baseline_v2_4_No_select_Hart6_UCB_0.1_20_400_6_CumRegret.csv",
    "./Results/Baseline_318_4_No_select_Levy_EI_0.1_20_400_20_CumRegret.csv",
    # "./Results/Baseline2_4_No_select_Hart6_UCB_0.1_20_400_6_CumRegret.csv",
    # "./Results/HCA_ini_4_No_select_Hart6_UCB_True_20_400_6_CumRegret.csv",
    # "./Results/COCOA_ini_4_No_select_Hart6_UCB_True_20_400_6_CumRegret.csv",
    # ... 其他文件名
]

# Center_random_2024086_keepinitial_4_Random_select_Hart6_UCB_0.1_20_400_6_Regret.csv

# 定义自定义标签
labels = ['HCA','Standard BO', 'Hart6_UCB_Random_select-4-Center', 'Hart6_UCB_Random_select-4-Weight', 'Hart6_Random_AC_No_select']
colors = ['blue', 'red', 'green', 'orange', 'purple','black']

plt.figure(figsize=(4, 3))

# 2. 对每个文件进行迭代
for idx, file in enumerate(filenames_01):
    # 读取数据
    data = pd.read_csv(file, header=None)
    # 计算平均值和标准差
    averages = data.mean(axis=0)
    std_devs = data.std(axis=0)
    
    # 3. 绘制平均值和误差带
    plt.plot(averages, label=labels[idx], color=colors[idx])
    plt.fill_between(range(len(averages)), averages - std_devs, averages + std_devs, color=colors[idx], alpha=0.2)

plt.title("CumRegret")
plt.xlabel("Index")
plt.ylabel("Average Value")
plt.legend()
plt.grid(True)
plt.show()

# %%
import pandas as pd
import matplotlib.pyplot as plt
import numpy as np

# 1. 创建文件名列表
filenames_01 = [
    # "./Results/2025110_4_No_select_Hart6_UCB_True_20_400_6_CumRegret.csv",
    # "./Results/HCA_v3_4_No_select_Hart6_UCB_True_20_400_6_CumRegret.csv",
    "./Results/HCA_KNN_v1_4_No_select_Levy_TS_0.1_20_400_20_CumRegret.csv",
    # "./Results/HCA_v5_4_No_select_Hart6_UCB_0.1_20_400_6_CumRegret.csv",
    # "./Results/COCOA_4_No_select_Hart6_UCB_True_20_400_6_CumRegret.csv",
    # "./Results/COCOA_v4_4_No_select_Hart6_UCB_0.1_20_400_6_CumRegret.csv",
    # "./Results/HCA_multi_baseline_v2_4_No_select_Hart6_UCB_0.1_20_400_6_CumRegret.csv",
    "./Results/Baseline_318_4_No_select_Levy_TS_0.1_20_400_20_CumRegret.csv",
    # "./Results/Baseline2_4_No_select_Hart6_UCB_0.1_20_400_6_CumRegret.csv",
    # "./Results/HCA_ini_4_No_select_Hart6_UCB_True_20_400_6_CumRegret.csv",
    # "./Results/COCOA_ini_4_No_select_Hart6_UCB_True_20_400_6_CumRegret.csv",
    # ... 其他文件名
]

# Center_random_2024086_keepinitial_4_Random_select_Hart6_UCB_0.1_20_400_6_Regret.csv

# 定义自定义标签
labels = ['HCA','Standard BO', 'Hart6_UCB_Random_select-4-Center', 'Hart6_UCB_Random_select-4-Weight', 'Hart6_Random_AC_No_select']
colors = ['blue', 'red', 'green', 'orange', 'purple','black']

plt.figure(figsize=(4, 3))

# 2. 对每个文件进行迭代
for idx, file in enumerate(filenames_01):
    # 读取数据
    data = pd.read_csv(file, header=None)
    # 计算平均值和标准差
    averages = data.mean(axis=0)
    std_devs = data.std(axis=0)
    
    # 3. 绘制平均值和误差带
    plt.plot(averages, label=labels[idx], color=colors[idx])
    plt.fill_between(range(len(averages)), averages - std_devs, averages + std_devs, color=colors[idx], alpha=0.2)

plt.title("CumRegret")
plt.xlabel("Index")
plt.ylabel("Average Value")
plt.legend()
plt.grid(True)
plt.show()

# %%
import pandas as pd
import matplotlib.pyplot as plt
import numpy as np

# 1. 创建文件名列表
filenames_01 = [
    # "./Results/2025110_4_No_select_Hart6_UCB_True_20_400_6_CumRegret.csv",
    # "./Results/HCA_v3_4_No_select_Hart6_UCB_True_20_400_6_CumRegret.csv",
    "./Results/HCA_KNN_v1_4_No_select_Powell_UCB_0.1_20_400_50_CumRegret.csv",
    # "./Results/HCA_v5_4_No_select_Hart6_UCB_0.1_20_400_6_CumRegret.csv",
    # "./Results/COCOA_4_No_select_Hart6_UCB_True_20_400_6_CumRegret.csv",
    # "./Results/COCOA_v4_4_No_select_Hart6_UCB_0.1_20_400_6_CumRegret.csv",
    # "./Results/HCA_multi_baseline_v2_4_No_select_Hart6_UCB_0.1_20_400_6_CumRegret.csv",
    "./Results/Baseline_318_4_No_select_Powell_UCB_0.1_20_400_50_CumRegret.csv",
    # "./Results/Baseline2_4_No_select_Hart6_UCB_0.1_20_400_6_CumRegret.csv",
    # "./Results/HCA_ini_4_No_select_Hart6_UCB_True_20_400_6_CumRegret.csv",
    # "./Results/COCOA_ini_4_No_select_Hart6_UCB_True_20_400_6_CumRegret.csv",
    # ... 其他文件名
]

# Center_random_2024086_keepinitial_4_Random_select_Hart6_UCB_0.1_20_400_6_Regret.csv

# 定义自定义标签
labels = ['HCA','Standard BO', 'Hart6_UCB_Random_select-4-Center', 'Hart6_UCB_Random_select-4-Weight', 'Hart6_Random_AC_No_select']
colors = ['blue', 'red', 'green', 'orange', 'purple','black']

plt.figure(figsize=(4, 3))

# 2. 对每个文件进行迭代
for idx, file in enumerate(filenames_01):
    # 读取数据
    data = pd.read_csv(file, header=None)
    # 计算平均值和标准差
    averages = data.mean(axis=0)
    std_devs = data.std(axis=0)
    
    # 3. 绘制平均值和误差带
    plt.plot(averages, label=labels[idx], color=colors[idx])
    plt.fill_between(range(len(averages)), averages - std_devs, averages + std_devs, color=colors[idx], alpha=0.2)

plt.title("CumRegret")
plt.xlabel("Index")
plt.ylabel("Average Value")
plt.legend()
plt.grid(True)
plt.show()

# %%
import pandas as pd
import matplotlib.pyplot as plt
import numpy as np

# 1. 创建文件名列表
filenames_01 = [
    # "./Results/2025110_4_No_select_Hart6_UCB_True_20_400_6_CumRegret.csv",
    # "./Results/HCA_v3_4_No_select_Hart6_UCB_True_20_400_6_CumRegret.csv",
    "./Results/HCA_KNN_v1_4_No_select_Powell_EI_0.1_20_400_50_CumRegret.csv",
    # "./Results/HCA_v5_4_No_select_Hart6_UCB_0.1_20_400_6_CumRegret.csv",
    # "./Results/COCOA_4_No_select_Hart6_UCB_True_20_400_6_CumRegret.csv",
    # "./Results/COCOA_v4_4_No_select_Hart6_UCB_0.1_20_400_6_CumRegret.csv",
    # "./Results/HCA_multi_baseline_v2_4_No_select_Hart6_UCB_0.1_20_400_6_CumRegret.csv",
    "./Results/Baseline_318_4_No_select_Powell_EI_0.1_20_400_50_CumRegret.csv",
    # "./Results/Baseline2_4_No_select_Hart6_UCB_0.1_20_400_6_CumRegret.csv",
    # "./Results/HCA_ini_4_No_select_Hart6_UCB_True_20_400_6_CumRegret.csv",
    # "./Results/COCOA_ini_4_No_select_Hart6_UCB_True_20_400_6_CumRegret.csv",
    # ... 其他文件名
]

# Center_random_2024086_keepinitial_4_Random_select_Hart6_UCB_0.1_20_400_6_Regret.csv

# 定义自定义标签
labels = ['HCA','Standard BO', 'Hart6_UCB_Random_select-4-Center', 'Hart6_UCB_Random_select-4-Weight', 'Hart6_Random_AC_No_select']
colors = ['blue', 'red', 'green', 'orange', 'purple','black']

plt.figure(figsize=(4, 3))

# 2. 对每个文件进行迭代
for idx, file in enumerate(filenames_01):
    # 读取数据
    data = pd.read_csv(file, header=None)
    # 计算平均值和标准差
    averages = data.mean(axis=0)
    std_devs = data.std(axis=0)
    
    # 3. 绘制平均值和误差带
    plt.plot(averages, label=labels[idx], color=colors[idx])
    plt.fill_between(range(len(averages)), averages - std_devs, averages + std_devs, color=colors[idx], alpha=0.2)

plt.title("CumRegret")
plt.xlabel("Index")
plt.ylabel("Average Value")
plt.legend()
plt.grid(True)
plt.show()

# %%
import pandas as pd
import matplotlib.pyplot as plt
import numpy as np

# 1. 创建文件名列表
filenames_01 = [
    # "./Results/2025110_4_No_select_Hart6_UCB_True_20_400_6_CumRegret.csv",
    # "./Results/HCA_v3_4_No_select_Hart6_UCB_True_20_400_6_CumRegret.csv",
    "./Results/HCA_KNN_v1_4_No_select_Powell_TS_0.1_20_400_50_CumRegret.csv",
    # "./Results/HCA_v5_4_No_select_Hart6_UCB_0.1_20_400_6_CumRegret.csv",
    # "./Results/COCOA_4_No_select_Hart6_UCB_True_20_400_6_CumRegret.csv",
    # "./Results/COCOA_v4_4_No_select_Hart6_UCB_0.1_20_400_6_CumRegret.csv",
    # "./Results/HCA_multi_baseline_v2_4_No_select_Hart6_UCB_0.1_20_400_6_CumRegret.csv",
    "./Results/Baseline_318_4_No_select_Powell_TS_0.1_20_400_50_CumRegret.csv",
    # "./Results/Baseline2_4_No_select_Hart6_UCB_0.1_20_400_6_CumRegret.csv",
    # "./Results/HCA_ini_4_No_select_Hart6_UCB_True_20_400_6_CumRegret.csv",
    # "./Results/COCOA_ini_4_No_select_Hart6_UCB_True_20_400_6_CumRegret.csv",
    # ... 其他文件名
]

# Center_random_2024086_keepinitial_4_Random_select_Hart6_UCB_0.1_20_400_6_Regret.csv

# 定义自定义标签
labels = ['HCA','Standard BO', 'Hart6_UCB_Random_select-4-Center', 'Hart6_UCB_Random_select-4-Weight', 'Hart6_Random_AC_No_select']
colors = ['blue', 'red', 'green', 'orange', 'purple','black']

plt.figure(figsize=(4, 3))

# 2. 对每个文件进行迭代
for idx, file in enumerate(filenames_01):
    # 读取数据
    data = pd.read_csv(file, header=None)
    # 计算平均值和标准差
    averages = data.mean(axis=0)
    std_devs = data.std(axis=0)
    
    # 3. 绘制平均值和误差带
    plt.plot(averages, label=labels[idx], color=colors[idx])
    plt.fill_between(range(len(averages)), averages - std_devs, averages + std_devs, color=colors[idx], alpha=0.2)

plt.title("CumRegret")
plt.xlabel("Index")
plt.ylabel("Average Value")
plt.legend()
plt.grid(True)
plt.show()

# %%
import pandas as pd
import matplotlib.pyplot as plt
import numpy as np

# 1. 创建文件名列表
filenames_01 = [
    # "./Results/2025110_4_No_select_Hart6_UCB_True_20_400_6_CumRegret.csv",
    # "./Results/HCA_v3_4_No_select_Hart6_UCB_True_20_400_6_CumRegret.csv",
    "./Results/HCA_multi_4_No_select_Hart6_EI_0.1_20_400_6_CumRegret.csv",
    # "./Results/HCA_v5_4_No_select_Hart6_UCB_0.1_20_400_6_CumRegret.csv",
    # "./Results/COCOA_4_No_select_Hart6_UCB_True_20_400_6_CumRegret.csv",
    # "./Results/COCOA_v4_4_No_select_Hart6_UCB_0.1_20_400_6_CumRegret.csv",
    "./Results/HCA_multi_baseline_v2_4_No_select_Hart6_EI_0.1_20_400_6_CumRegret.csv",
    # "./Results/Baseline2_4_No_select_Hart6_UCB_0.1_20_400_6_CumRegret.csv",
    # "./Results/HCA_ini_4_No_select_Hart6_UCB_True_20_400_6_CumRegret.csv",
    # "./Results/COCOA_ini_4_No_select_Hart6_UCB_True_20_400_6_CumRegret.csv",
    # ... 其他文件名
]

# Center_random_2024086_keepinitial_4_Random_select_Hart6_UCB_0.1_20_400_6_Regret.csv

# 定义自定义标签
labels = ['HCA','Standard BO', 'Hart6_UCB_Random_select-4-Center', 'Hart6_UCB_Random_select-4-Weight', 'Hart6_Random_AC_No_select']
colors = ['blue', 'red', 'green', 'orange', 'purple','black']

plt.figure(figsize=(4, 3))

# 2. 对每个文件进行迭代
for idx, file in enumerate(filenames_01):
    # 读取数据
    data = pd.read_csv(file, header=None)
    # 计算平均值和标准差
    averages = data.mean(axis=0)
    std_devs = data.std(axis=0)
    
    # 3. 绘制平均值和误差带
    plt.plot(averages, label=labels[idx], color=colors[idx])
    plt.fill_between(range(len(averages)), averages - std_devs, averages + std_devs, color=colors[idx], alpha=0.2)

plt.title("CumRegret")
plt.xlabel("Index")
plt.ylabel("Average Value")
plt.legend()
plt.grid(True)
plt.show()

# %%
import pandas as pd
import matplotlib.pyplot as plt
import numpy as np

# 1. 创建文件名列表
filenames_01 = [
    # "./Results/2025110_4_No_select_Hart6_UCB_True_20_400_6_CumRegret.csv",
    # "./Results/HCA_v3_4_No_select_Hart6_UCB_True_20_400_6_CumRegret.csv",
    "./Results/HCA_multi_4_No_select_Hart6_TS_0.1_20_400_6_CumRegret.csv",
    # "./Results/HCA_v5_4_No_select_Hart6_UCB_0.1_20_400_6_CumRegret.csv",
    # "./Results/COCOA_4_No_select_Hart6_UCB_True_20_400_6_CumRegret.csv",
    # "./Results/COCOA_v4_4_No_select_Hart6_UCB_0.1_20_400_6_CumRegret.csv",
    "./Results/HCA_multi_baseline_v2_4_No_select_Hart6_TS_0.1_20_400_6_CumRegret.csv",
    # "./Results/Baseline2_4_No_select_Hart6_UCB_0.1_20_400_6_CumRegret.csv",
    # "./Results/HCA_ini_4_No_select_Hart6_UCB_True_20_400_6_CumRegret.csv",
    # "./Results/COCOA_ini_4_No_select_Hart6_UCB_True_20_400_6_CumRegret.csv",
    # ... 其他文件名
]

# Center_random_2024086_keepinitial_4_Random_select_Hart6_UCB_0.1_20_400_6_Regret.csv

# 定义自定义标签
labels = ['HCA','Standard BO', 'Hart6_UCB_Random_select-4-Center', 'Hart6_UCB_Random_select-4-Weight', 'Hart6_Random_AC_No_select']
colors = ['blue', 'red', 'green', 'orange', 'purple','black']

plt.figure(figsize=(4, 3))

# 2. 对每个文件进行迭代
for idx, file in enumerate(filenames_01):
    # 读取数据
    data = pd.read_csv(file, header=None)
    # 计算平均值和标准差
    averages = data.mean(axis=0)
    std_devs = data.std(axis=0)
    
    # 3. 绘制平均值和误差带
    plt.plot(averages, label=labels[idx], color=colors[idx])
    plt.fill_between(range(len(averages)), averages - std_devs, averages + std_devs, color=colors[idx], alpha=0.2)

plt.title("CumRegret")
plt.xlabel("Index")
plt.ylabel("Average Value")
plt.legend()
plt.grid(True)
plt.show()

# %%
import pandas as pd
import matplotlib.pyplot as plt
import numpy as np

# 1. 创建文件名列表
filenames_01 = [
    # "./Results/2025110_4_No_select_Hart6_UCB_True_20_400_6_CumRegret.csv",
    # "./Results/HCA_v3_4_No_select_Hart6_UCB_True_20_400_6_CumRegret.csv",
    "./Results/HCA_v4_4_No_select_Hart6_UCB_0.1_20_400_6_CumRegret.csv",
    # "./Results/COCOA_4_No_select_Hart6_UCB_True_20_400_6_CumRegret.csv",
    "./Results/Baseline_4_No_select_Hart6_UCB_Heter_20_400_6_CumRegret.csv",
    "./Results/Baseline2_4_No_select_Hart6_UCB_0.1_20_400_6_CumRegret.csv",
    # "./Results/HCA_ini_4_No_select_Hart6_UCB_True_20_400_6_CumRegret.csv",
    # "./Results/COCOA_ini_4_No_select_Hart6_UCB_True_20_400_6_CumRegret.csv",
    # ... 其他文件名
]

# Center_random_2024086_keepinitial_4_Random_select_Hart6_UCB_0.1_20_400_6_Regret.csv

# 定义自定义标签
labels = ['HCA_v4', 'Standard BO','Standard BO', 'Hart6_UCB_Random_select-4-Center', 'Hart6_UCB_Random_select-4-Weight', 'Hart6_Random_AC_No_select']
colors = ['blue', 'red', 'green', 'orange', 'purple','black']

plt.figure(figsize=(12, 7))

# 2. 对每个文件进行迭代
for idx, file in enumerate(filenames_01):
    # 读取数据
    data = pd.read_csv(file, header=None)
    # 计算平均值和标准差
    averages = data.mean(axis=0)
    std_devs = data.std(axis=0)
    
    # 3. 绘制平均值和误差带
    plt.plot(averages, label=labels[idx], color=colors[idx])
    plt.fill_between(range(len(averages)), averages - std_devs, averages + std_devs, color=colors[idx], alpha=0.2)

plt.title("CumRegret")
plt.xlabel("Index")
plt.ylabel("Average Value")
plt.legend()
plt.grid(True)
plt.show()

# %%
import pandas as pd
import matplotlib.pyplot as plt
import numpy as np

# 1. 创建文件名列表
filenames_01 = [
    # "./Results/2025110_4_No_select_Hart6_UCB_True_20_400_6_CumRegret.csv",
    # "./Results/HCA_v3_4_No_select_Hart6_UCB_True_20_400_6_CumRegret.csv",
    "./Results/HCA_v4_4_No_select_Hart6_UCB_0.1_20_400_6_CumRegret.csv",
    # "./Results/COCOA_4_No_select_Hart6_UCB_True_20_400_6_CumRegret.csv",
    "./Results/Baseline_4_No_select_Hart6_UCB_Heter_20_400_6_CumRegret.csv",
    "./Results/COCOA_v3_4_No_select_Hart6_UCB_0.1_20_400_6_CumRegret.csv",
    # "./Results/Baseline2_4_No_select_Hart6_UCB_0.1_20_400_6_CumRegret.csv",
    # "./Results/HCA_ini_4_No_select_Hart6_UCB_True_20_400_6_CumRegret.csv",
    # "./Results/COCOA_ini_4_No_select_Hart6_UCB_True_20_400_6_CumRegret.csv",
    # ... 其他文件名
]

# Center_random_2024086_keepinitial_4_Random_select_Hart6_UCB_0.1_20_400_6_Regret.csv

# 定义自定义标签
labels = ['HCA', 'Standard BO','COCOA', 'Hart6_UCB_Random_select-4-Center', 'Hart6_UCB_Random_select-4-Weight', 'Hart6_Random_AC_No_select']
colors = ['blue', 'red', 'green', 'orange', 'purple','black']

plt.figure(figsize=(12, 7))

# 2. 对每个文件进行迭代
for idx, file in enumerate(filenames_01):
    # 读取数据
    data = pd.read_csv(file, header=None)
    # 计算平均值和标准差
    averages = data.mean(axis=0)
    std_devs = data.std(axis=0)
    
    # 3. 绘制平均值和误差带
    plt.plot(averages, label=labels[idx], color=colors[idx])
    plt.fill_between(range(len(averages)), averages - std_devs, averages + std_devs, color=colors[idx], alpha=0.2)

plt.title("CumRegret")
plt.xlabel("Index")
plt.ylabel("Average Value")
plt.legend()
plt.grid(True)
plt.show()

# %%
import pandas as pd
import matplotlib.pyplot as plt
import numpy as np

# 1. 创建文件名列表
filenames_01 = [
    # "./Results/2025110_4_No_select_Hart6_UCB_True_20_400_6_CumRegret.csv",
    "./Results/HCA_v4_4_No_select_Hart6_UCB_0.1_20_400_6_SimRegret.csv",
    "./Results/COCOA_4_No_select_Hart6_UCB_True_20_400_6_SimRegret.csv",
    "./Results/Baseline_4_No_select_Hart6_UCB_Heter_20_400_6_SimRegret.csv",
    "./Results/HCA_ini_4_No_select_Hart6_UCB_True_20_400_6_SimRegret.csv",
    "./Results/COCOA_ini_4_No_select_Hart6_UCB_True_20_400_6_SimRegret.csv",
    # "./Results/Baseline2_4_No_select_Hart6_UCB_0.1_20_400_6_SimRegret.csv",
    # ... 其他文件名
]

# Center_random_2024086_keepinitial_4_Random_select_Hart6_UCB_0.1_20_400_6_Regret.csv

# 定义自定义标签
labels = ['HCA', 'COCOA', 'Standard BO', 'Hart6_UCB_Random_select-4-Center', 'Hart6_UCB_Random_select-4-Weight', 'Hart6_Random_AC_No_select']
colors = ['blue', 'red', 'green', 'orange', 'purple','black']

plt.figure(figsize=(12, 7))

# 2. 对每个文件进行迭代
for idx, file in enumerate(filenames_01):
    # 读取数据
    data = pd.read_csv(file, header=None)
    # 计算平均值和标准差
    averages = data.mean(axis=0)
    std_devs = data.std(axis=0)
    
    # 3. 绘制平均值和误差带
    plt.plot(averages, label=labels[idx], color=colors[idx])
    plt.fill_between(range(len(averages)), averages - std_devs, averages + std_devs, color=colors[idx], alpha=0.2)

plt.title("SimRegret")
plt.xlabel("Index")
plt.ylabel("Average Value")
plt.legend()
plt.grid(True)
plt.show()

# %%
import pandas as pd
import matplotlib.pyplot as plt
import numpy as np

# 1. 创建文件名列表
filenames_01 = [
    # "./Results/2025110_4_No_select_Hart6_UCB_True_20_400_6_CumRegret.csv",
    # "./Results/HCA_v3_4_No_select_Hart6_UCB_True_20_400_6_CumRegret.csv",
    "./Results/HCA_v4_4_No_select_Hart6_UCB_0.1_20_400_6_CumRegret.csv",
    # "./Results/HCA_v5_4_No_select_Hart6_UCB_0.1_20_400_6_CumRegret.csv",
    # "./Results/COCOA_4_No_select_Hart6_UCB_True_20_400_6_CumRegret.csv",
    "./Results/COCOA_v4_4_No_select_Hart6_UCB_0.1_20_400_6_CumRegret.csv",
    "./Results/Baseline_4_No_select_Hart6_UCB_Heter_20_400_6_CumRegret.csv",
    # "./Results/Baseline2_4_No_select_Hart6_UCB_0.1_20_400_6_CumRegret.csv",
    # "./Results/HCA_ini_4_No_select_Hart6_UCB_True_20_400_6_CumRegret.csv",
    # "./Results/COCOA_ini_4_No_select_Hart6_UCB_True_20_400_6_CumRegret.csv",
    # ... 其他文件名
]

# Center_random_2024086_keepinitial_4_Random_select_Hart6_UCB_0.1_20_400_6_Regret.csv

# 定义自定义标签
labels = ['HCA', 'HCA+C','Standard BO', 'Hart6_UCB_Random_select-4-Center', 'Hart6_UCB_Random_select-4-Weight', 'Hart6_Random_AC_No_select']
colors = ['blue', 'red', 'green', 'orange', 'purple','black']

plt.figure(figsize=(4, 3))

# 2. 对每个文件进行迭代
for idx, file in enumerate(filenames_01):
    # 读取数据
    data = pd.read_csv(file, header=None)
    # 计算平均值和标准差
    averages = data.mean(axis=0)
    std_devs = data.std(axis=0)
    
    # 3. 绘制平均值和误差带
    plt.plot(averages, label=labels[idx], color=colors[idx])
    plt.fill_between(range(len(averages)), averages - std_devs, averages + std_devs, color=colors[idx], alpha=0.2)

plt.title("CumRegret")
plt.xlabel("Index")
plt.ylabel("Average Value")
plt.legend()
plt.grid(True)
plt.show()

# %%
import pandas as pd
import matplotlib.pyplot as plt
import numpy as np

# 1. 创建文件名列表
filenames_01 = [
    # "./Results/2025110_4_No_select_Hart6_UCB_True_20_400_6_CumRegret.csv",
    # "./Results/HCA_v3_4_No_select_Hart6_UCB_True_20_400_6_CumRegret.csv",
    # "./Results/HCA_v4_4_No_select_Hart6_UCB_0.1_20_400_6_CumRegret.csv",
    # "./Results/HCA_v5_4_No_select_Hart6_UCB_0.1_20_400_6_CumRegret.csv",
    # "./Results/COCOA_4_No_select_Hart6_UCB_True_20_400_6_CumRegret.csv",
    # "./Results/COCOA_v4_4_No_select_Hart6_UCB_0.1_20_400_6_CumRegret.csv",
    "./Results/Baseline_4_No_select_Hart6_UCB_Heter_20_400_6_CumRegret.csv",
    "./Results/HCA_multi_4_No_select_Hart6_UCB_0.1_20_400_6_CumRegret.csv",
    # "./Results/Baseline2_4_No_select_Hart6_UCB_0.1_20_400_6_CumRegret.csv",
    # "./Results/HCA_ini_4_No_select_Hart6_UCB_True_20_400_6_CumRegret.csv",
    # "./Results/COCOA_ini_4_No_select_Hart6_UCB_True_20_400_6_CumRegret.csv",
    # ... 其他文件名
]

# Center_random_2024086_keepinitial_4_Random_select_Hart6_UCB_0.1_20_400_6_Regret.csv

# 定义自定义标签
labels = ['Base_GpyTorch', 'HCA_multi','Standard BO', 'Hart6_UCB_Random_select-4-Center', 'Hart6_UCB_Random_select-4-Weight', 'Hart6_Random_AC_No_select']
colors = ['blue', 'red', 'green', 'orange', 'purple','black']

plt.figure(figsize=(4, 3))

# 2. 对每个文件进行迭代
for idx, file in enumerate(filenames_01):
    # 读取数据
    data = pd.read_csv(file, header=None)
    # 计算平均值和标准差
    averages = data.mean(axis=0)
    std_devs = data.std(axis=0)
    
    # 3. 绘制平均值和误差带
    plt.plot(averages, label=labels[idx], color=colors[idx])
    plt.fill_between(range(len(averages)), averages - std_devs, averages + std_devs, color=colors[idx], alpha=0.2)

plt.title("CumRegret")
plt.xlabel("Index")
plt.ylabel("Average Value")
plt.legend()
plt.grid(True)
plt.show()

# %%
import pandas as pd
import matplotlib.pyplot as plt
import numpy as np

# 1. 创建文件名列表
filenames_01 = [
    # "./Results/2025110_4_No_select_Hart6_UCB_True_20_400_6_CumRegret.csv",
    # "./Results/HCA_v3_4_No_select_Hart6_UCB_True_20_400_6_CumRegret.csv",
    "./Results/HCA_v4_4_No_select_Hart6_UCB_0.1_20_400_6_CumRegret.csv",
    # "./Results/HCA_v5_4_No_select_Hart6_UCB_0.1_20_400_6_CumRegret.csv",
    # "./Results/COCOA_4_No_select_Hart6_UCB_True_20_400_6_CumRegret.csv",
    "./Results/COCOA_v4_4_No_select_Hart6_UCB_0.1_20_400_6_CumRegret.csv",
    "./Results/Baseline_4_No_select_Hart6_UCB_Heter_20_400_6_CumRegret.csv",
    # "./Results/Baseline2_4_No_select_Hart6_UCB_0.1_20_400_6_CumRegret.csv",
    # "./Results/HCA_ini_4_No_select_Hart6_UCB_True_20_400_6_CumRegret.csv",
    # "./Results/COCOA_ini_4_No_select_Hart6_UCB_True_20_400_6_CumRegret.csv",
    # ... 其他文件名
]

# Center_random_2024086_keepinitial_4_Random_select_Hart6_UCB_0.1_20_400_6_Regret.csv

# 定义自定义标签
labels = ['HCA', 'HCA+C','Standard BO', 'Hart6_UCB_Random_select-4-Center', 'Hart6_UCB_Random_select-4-Weight', 'Hart6_Random_AC_No_select']
colors = ['blue', 'red', 'green', 'orange', 'purple','black']

plt.figure(figsize=(4, 3))

# 2. 对每个文件进行迭代
for idx, file in enumerate(filenames_01):
    # 读取数据
    data = pd.read_csv(file, header=None)
    # 计算平均值和标准差
    averages = data.mean(axis=0)
    std_devs = data.std(axis=0)
    
    # 3. 绘制平均值和误差带
    plt.plot(averages, label=labels[idx], color=colors[idx])
    plt.fill_between(range(len(averages)), averages - std_devs, averages + std_devs, color=colors[idx], alpha=0.2)

plt.title("CumRegret")
plt.xlabel("Index")
plt.ylabel("Average Value")
plt.legend()
plt.grid(True)
plt.show()

# %%
import pandas as pd
import matplotlib.pyplot as plt
import numpy as np

# 1. 创建文件名列表
filenames_01 = [
    # "./Results/2025110_4_No_select_Hart6_UCB_True_20_400_6_CumRegret.csv",
    # "./Results/HCA_v3_4_No_select_Hart6_UCB_True_20_400_6_CumRegret.csv",
    "./Results/HCA_v5_4_No_select_Hart6_UCB_0.1_20_400_6_SimRegret.csv",
    # "./Results/HCA_v5_4_No_select_Hart6_UCB_0.1_20_400_6_CumRegret.csv",
    # "./Results/COCOA_4_No_select_Hart6_UCB_True_20_400_6_CumRegret.csv",
    "./Results/COCOA_v4_4_No_select_Hart6_UCB_0.1_20_400_6_SimRegret.csv",
    "./Results/Baseline_4_No_select_Hart6_UCB_Heter_20_400_6_SimRegret.csv",
    # "./Results/Baseline2_4_No_select_Hart6_UCB_0.1_20_400_6_SimRegret.csv",
    # "./Results/HCA_ini_4_No_select_Hart6_UCB_True_20_400_6_CumRegret.csv",
    # "./Results/COCOA_ini_4_No_select_Hart6_UCB_True_20_400_6_CumRegret.csv",
    # ... 其他文件名
]

# Center_random_2024086_keepinitial_4_Random_select_Hart6_UCB_0.1_20_400_6_Regret.csv

# 定义自定义标签
labels = ['HCA', 'HCA+C','Standard BO', 'Hart6_UCB_Random_select-4-Center', 'Hart6_UCB_Random_select-4-Weight', 'Hart6_Random_AC_No_select']
colors = ['blue', 'red', 'green', 'orange', 'purple','black']

plt.figure(figsize=(4, 3))

# 2. 对每个文件进行迭代
for idx, file in enumerate(filenames_01):
    # 读取数据
    data = pd.read_csv(file, header=None)
    # 计算平均值和标准差
    averages = data.mean(axis=0)
    std_devs = data.std(axis=0)
    
    # 3. 绘制平均值和误差带
    plt.plot(averages, label=labels[idx], color=colors[idx])
    plt.fill_between(range(len(averages)), averages - std_devs, averages + std_devs, color=colors[idx], alpha=0.2)

plt.title("CumRegret")
plt.xlabel("Index")
plt.ylabel("Average Value")
plt.legend()
plt.grid(True)
plt.show()

# %%
import pandas as pd
import matplotlib.pyplot as plt
import numpy as np

# 1. 创建文件名列表
filenames_01 = [
    # "./Results/2025110_4_No_select_Hart6_UCB_True_20_400_6_CumRegret.csv",
    # "./Results/HCA_v3_4_No_select_Hart6_UCB_True_20_400_6_CumRegret.csv",
    "./Results/HCA_v4_4_No_select_Hart6_EI_0.1_20_400_6_CumRegret.csv",
    "./Results/COCOA_v4_4_No_select_Hart6_EI_0.1_20_400_6_CumRegret.csv",
    "./Results/Baseline_4_No_select_Hart6_EI_Heter_20_400_6_CumRegret.csv",
    # "./Results/Baseline2_4_No_select_Hart6_UCB_0.1_20_400_6_CumRegret.csv",
    # "./Results/HCA_ini_4_No_select_Hart6_UCB_True_20_400_6_CumRegret.csv",
    # "./Results/COCOA_ini_4_No_select_Hart6_UCB_True_20_400_6_CumRegret.csv",
    # ... 其他文件名
]

# Center_random_2024086_keepinitial_4_Random_select_Hart6_UCB_0.1_20_400_6_Regret.csv

# 定义自定义标签
labels = ['HCA', 'HCA+C','Standard BO', 'Hart6_UCB_Random_select-4-Center', 'Hart6_UCB_Random_select-4-Weight', 'Hart6_Random_AC_No_select']
colors = ['blue', 'red', 'green', 'orange', 'purple','black']

plt.figure(figsize=(4, 3))

# 2. 对每个文件进行迭代
for idx, file in enumerate(filenames_01):
    # 读取数据
    data = pd.read_csv(file, header=None)
    # 计算平均值和标准差
    averages = data.mean(axis=0)
    std_devs = data.std(axis=0)
    
    # 3. 绘制平均值和误差带
    plt.plot(averages, label=labels[idx], color=colors[idx])
    plt.fill_between(range(len(averages)), averages - std_devs, averages + std_devs, color=colors[idx], alpha=0.2)

plt.title("CumRegret")
plt.xlabel("Index")
plt.ylabel("Average Value")
plt.legend()
plt.grid(True)
plt.show()

# %%
import pandas as pd
import matplotlib.pyplot as plt
import numpy as np

# 1. 创建文件名列表
filenames_01 = [
    # "./Results/2025110_4_No_select_Hart6_UCB_True_20_400_6_CumRegret.csv",
    # "./Results/HCA_v3_4_No_select_Hart6_UCB_True_20_400_6_CumRegret.csv",
    "./Results/HCA_v4_4_No_select_Hart6_TS_0.1_20_400_6_CumRegret.csv",
    "./Results/COCOA_v4_4_No_select_Hart6_TS_0.1_20_400_6_CumRegret.csv",
    "./Results/Baseline_4_No_select_Hart6_TS_Heter_20_400_6_CumRegret.csv",
    # "./Results/Baseline2_4_No_select_Hart6_UCB_0.1_20_400_6_CumRegret.csv",
    # "./Results/HCA_ini_4_No_select_Hart6_UCB_True_20_400_6_CumRegret.csv",
    # "./Results/COCOA_ini_4_No_select_Hart6_UCB_True_20_400_6_CumRegret.csv",
    # ... 其他文件名
]

# Center_random_2024086_keepinitial_4_Random_select_Hart6_UCB_0.1_20_400_6_Regret.csv

# 定义自定义标签
labels = ['HCA', 'HCA+C','Standard BO', 'Hart6_UCB_Random_select-4-Center', 'Hart6_UCB_Random_select-4-Weight', 'Hart6_Random_AC_No_select']
colors = ['blue', 'red', 'green', 'orange', 'purple','black']

plt.figure(figsize=(4, 3))

# 2. 对每个文件进行迭代
for idx, file in enumerate(filenames_01):
    # 读取数据
    data = pd.read_csv(file, header=None)
    # 计算平均值和标准差
    averages = data.mean(axis=0)
    std_devs = data.std(axis=0)
    
    # 3. 绘制平均值和误差带
    plt.plot(averages, label=labels[idx], color=colors[idx])
    plt.fill_between(range(len(averages)), averages - std_devs, averages + std_devs, color=colors[idx], alpha=0.2)

plt.title("CumRegret")
plt.xlabel("Index")
plt.ylabel("Average Value")
plt.legend()
plt.grid(True)
plt.show()

# %%
import pandas as pd
import matplotlib.pyplot as plt
import numpy as np

# 1. 创建文件名列表
filenames_01 = [
    # "./Results/2025110_4_No_select_Hart6_UCB_True_20_400_6_CumRegret.csv",
    # "./Results/HCA_v3_4_No_select_Hart6_UCB_True_20_400_6_CumRegret.csv",
    "./Results/HCA_v4_4_No_select_Levy_UCB_0.1_20_400_20_CumRegret.csv",
    # "./Results/COCOA_4_No_select_Hart6_UCB_True_20_400_6_CumRegret.csv",
    "./Results/COCOA_v4_4_No_select_Levy_UCB_0.1_20_400_20_CumRegret.csv",
    "./Results/Baseline_4_No_select_Levy_UCB_Heter_20_400_20_CumRegret.csv",
    # "./Results/Baseline2_4_No_select_Hart6_UCB_0.1_20_400_6_CumRegret.csv",
    # "./Results/HCA_ini_4_No_select_Hart6_UCB_True_20_400_6_CumRegret.csv",
    # "./Results/COCOA_ini_4_No_select_Hart6_UCB_True_20_400_6_CumRegret.csv",
    # ... 其他文件名
]

# Center_random_2024086_keepinitial_4_Random_select_Hart6_UCB_0.1_20_400_6_Regret.csv

# 定义自定义标签
labels = ['HCA', 'HCA+C','Standard BO', 'Hart6_UCB_Random_select-4-Center', 'Hart6_UCB_Random_select-4-Weight', 'Hart6_Random_AC_No_select']
colors = ['blue', 'red', 'green', 'orange', 'purple','black']

plt.figure(figsize=(4, 3))

# 2. 对每个文件进行迭代
for idx, file in enumerate(filenames_01):
    # 读取数据
    data = pd.read_csv(file, header=None)
    # 计算平均值和标准差
    averages = data.mean(axis=0)
    std_devs = data.std(axis=0)
    
    # 3. 绘制平均值和误差带
    plt.plot(averages, label=labels[idx], color=colors[idx])
    plt.fill_between(range(len(averages)), averages - std_devs, averages + std_devs, color=colors[idx], alpha=0.2)

plt.title("CumRegret")
plt.xlabel("Index")
plt.ylabel("Average Value")
plt.legend()
plt.grid(True)
plt.show()

# %%
import pandas as pd
import matplotlib.pyplot as plt
import numpy as np

# 1. 创建文件名列表
filenames_01 = [
    # "./Results/2025110_4_No_select_Hart6_UCB_True_20_400_6_CumRegret.csv",
    # "./Results/HCA_v3_4_No_select_Hart6_UCB_True_20_400_6_CumRegret.csv",
    "./Results/HCA_v4_4_No_select_Levy_EI_0.1_20_400_20_CumRegret.csv",    
    # "./Results/COCOA_4_No_select_Hart6_UCB_True_20_400_6_CumRegret.csv",
    "./Results/COCOA_v4_4_No_select_Levy_EI_0.1_20_400_20_CumRegret.csv",
    "./Results/Baseline_4_No_select_Levy_EI_Heter_20_400_20_CumRegret.csv",
    # "./Results/Baseline2_4_No_select_Hart6_UCB_0.1_20_400_6_CumRegret.csv",
    # "./Results/HCA_ini_4_No_select_Hart6_UCB_True_20_400_6_CumRegret.csv",
    # "./Results/COCOA_ini_4_No_select_Hart6_UCB_True_20_400_6_CumRegret.csv",
    # ... 其他文件名
]

# Center_random_2024086_keepinitial_4_Random_select_Hart6_UCB_0.1_20_400_6_Regret.csv

# 定义自定义标签
labels = ['HCA', 'HCA+C','Standard BO', 'Hart6_UCB_Random_select-4-Center', 'Hart6_UCB_Random_select-4-Weight', 'Hart6_Random_AC_No_select']
colors = ['blue', 'red', 'green', 'orange', 'purple','black']

plt.figure(figsize=(4, 3))

# 2. 对每个文件进行迭代
for idx, file in enumerate(filenames_01):
    # 读取数据
    data = pd.read_csv(file, header=None)
    # 计算平均值和标准差
    averages = data.mean(axis=0)
    std_devs = data.std(axis=0)
    
    # 3. 绘制平均值和误差带
    plt.plot(averages, label=labels[idx], color=colors[idx])
    plt.fill_between(range(len(averages)), averages - std_devs, averages + std_devs, color=colors[idx], alpha=0.2)

plt.title("CumRegret")
plt.xlabel("Index")
plt.ylabel("Average Value")
plt.legend()
plt.grid(True)
plt.show()

# %%
import pandas as pd
import matplotlib.pyplot as plt
import numpy as np

# 1. 创建文件名列表
filenames_01 = [
    # "./Results/2025110_4_No_select_Hart6_UCB_True_20_400_6_CumRegret.csv",
    # "./Results/HCA_v3_4_No_select_Hart6_UCB_True_20_400_6_CumRegret.csv",
    "./Results/HCA_v4_4_No_select_Levy_TS_0.1_20_400_20_CumRegret.csv",
    # "./Results/COCOA_4_No_select_Hart6_UCB_True_20_400_6_CumRegret.csv",
    "./Results/COCOA_v4_4_No_select_Levy_TS_0.1_20_400_20_CumRegret.csv",
    "./Results/Baseline_4_No_select_Levy_TS_Heter_20_400_20_CumRegret.csv",
    # "./Results/Baseline2_4_No_select_Hart6_UCB_0.1_20_400_6_CumRegret.csv",
    # "./Results/HCA_ini_4_No_select_Hart6_UCB_True_20_400_6_CumRegret.csv",
    # "./Results/COCOA_ini_4_No_select_Hart6_UCB_True_20_400_6_CumRegret.csv",
    # ... 其他文件名
]

# Center_random_2024086_keepinitial_4_Random_select_Hart6_UCB_0.1_20_400_6_Regret.csv

# 定义自定义标签
labels = ['HCA', 'HCA+C','Standard BO', 'Hart6_UCB_Random_select-4-Center', 'Hart6_UCB_Random_select-4-Weight', 'Hart6_Random_AC_No_select']
colors = ['blue', 'red', 'green', 'orange', 'purple','black']

plt.figure(figsize=(4, 3))

# 2. 对每个文件进行迭代
for idx, file in enumerate(filenames_01):
    # 读取数据
    data = pd.read_csv(file, header=None)
    # 计算平均值和标准差
    averages = data.mean(axis=0)
    std_devs = data.std(axis=0)
    
    # 3. 绘制平均值和误差带
    plt.plot(averages, label=labels[idx], color=colors[idx])
    plt.fill_between(range(len(averages)), averages - std_devs, averages + std_devs, color=colors[idx], alpha=0.2)

plt.title("CumRegret")
plt.xlabel("Index")
plt.ylabel("Average Value")
plt.legend()
plt.grid(True)
plt.show()

# %%
import pandas as pd
import matplotlib.pyplot as plt
import numpy as np

# 1. 创建文件名列表
filenames_01 = [
    # "./Results/2025110_4_No_select_Hart6_UCB_True_20_400_6_CumRegret.csv",
    # "./Results/HCA_v3_4_No_select_Hart6_UCB_True_20_400_6_CumRegret.csv",
    "./Results/HCA_v4_4_No_select_Powell_UCB_0.1_20_400_50_CumRegret.csv",
    # "./Results/COCOA_4_No_select_Hart6_UCB_True_20_400_6_CumRegret.csv",
    "./Results/COCOA_v4_4_No_select_Powell_UCB_0.1_20_400_50_CumRegret.csv",
    "./Results/Baseline_4_No_select_Powell_UCB_Heter_20_400_50_CumRegret.csv",
    # "./Results/Baseline2_4_No_select_Hart6_UCB_0.1_20_400_6_CumRegret.csv",
    # "./Results/HCA_ini_4_No_select_Hart6_UCB_True_20_400_6_CumRegret.csv",
    # "./Results/COCOA_ini_4_No_select_Hart6_UCB_True_20_400_6_CumRegret.csv",
    # ... 其他文件名
]

# Center_random_2024086_keepinitial_4_Random_select_Hart6_UCB_0.1_20_400_6_Regret.csv

# 定义自定义标签
labels = ['HCA', 'HCA+C','Standard BO', 'Hart6_UCB_Random_select-4-Center', 'Hart6_UCB_Random_select-4-Weight', 'Hart6_Random_AC_No_select']
colors = ['blue', 'red', 'green', 'orange', 'purple','black']

plt.figure(figsize=(4, 3))

# 2. 对每个文件进行迭代
for idx, file in enumerate(filenames_01):
    # 读取数据
    data = pd.read_csv(file, header=None)
    # 计算平均值和标准差
    averages = data.mean(axis=0)
    std_devs = data.std(axis=0)
    
    # 3. 绘制平均值和误差带
    plt.plot(averages, label=labels[idx], color=colors[idx])
    plt.fill_between(range(len(averages)), averages - std_devs, averages + std_devs, color=colors[idx], alpha=0.2)

plt.title("CumRegret")
plt.xlabel("Index")
plt.ylabel("Average Value")
plt.legend()
plt.grid(True)
plt.show()

# %%
import pandas as pd
import matplotlib.pyplot as plt
import numpy as np

# 1. 创建文件名列表
filenames_01 = [
    # "./Results/2025110_4_No_select_Hart6_UCB_True_20_400_6_CumRegret.csv",
    # "./Results/HCA_v3_4_No_select_Hart6_UCB_True_20_400_6_CumRegret.csv",
    "./Results/HCA_v4_4_No_select_Powell_EI_0.1_20_400_50_CumRegret.csv",
    # "./Results/COCOA_4_No_select_Hart6_UCB_True_20_400_6_CumRegret.csv",
    "./Results/COCOA_v4_4_No_select_Powell_EI_0.1_20_400_50_CumRegret.csv",
    "./Results/Baseline_4_No_select_Powell_EI_Heter_20_400_50_CumRegret.csv",
    # "./Results/Baseline2_4_No_select_Hart6_UCB_0.1_20_400_6_CumRegret.csv",
    # "./Results/HCA_ini_4_No_select_Hart6_UCB_True_20_400_6_CumRegret.csv",
    # "./Results/COCOA_ini_4_No_select_Hart6_UCB_True_20_400_6_CumRegret.csv",
    # ... 其他文件名
]

# Center_random_2024086_keepinitial_4_Random_select_Hart6_UCB_0.1_20_400_6_Regret.csv

# 定义自定义标签
labels = ['HCA', 'HCA+C','Standard BO', 'Hart6_UCB_Random_select-4-Center', 'Hart6_UCB_Random_select-4-Weight', 'Hart6_Random_AC_No_select']
colors = ['blue', 'red', 'green', 'orange', 'purple','black']

plt.figure(figsize=(4, 3))

# 2. 对每个文件进行迭代
for idx, file in enumerate(filenames_01):
    # 读取数据
    data = pd.read_csv(file, header=None)
    # 计算平均值和标准差
    averages = data.mean(axis=0)
    std_devs = data.std(axis=0)
    
    # 3. 绘制平均值和误差带
    plt.plot(averages, label=labels[idx], color=colors[idx])
    plt.fill_between(range(len(averages)), averages - std_devs, averages + std_devs, color=colors[idx], alpha=0.2)

plt.title("CumRegret")
plt.xlabel("Index")
plt.ylabel("Average Value")
plt.legend()
plt.grid(True)
plt.show()

# %%
import pandas as pd
import matplotlib.pyplot as plt
import numpy as np

# 1. 创建文件名列表
filenames_01 = [
    # "./Results/2025110_4_No_select_Hart6_UCB_True_20_400_6_CumRegret.csv",
    # "./Results/HCA_v3_4_No_select_Hart6_UCB_True_20_400_6_CumRegret.csv",
    "./Results/HCA_v4_4_No_select_Powell_TS_0.1_20_400_50_CumRegret.csv",
    # "./Results/COCOA_4_No_select_Hart6_UCB_True_20_400_6_CumRegret.csv",
    "./Results/COCOA_v4_4_No_select_Powell_TS_0.1_20_400_50_CumRegret.csv",
    "./Results/Baseline_4_No_select_Powell_TS_Heter_20_400_50_CumRegret.csv",
    # "./Results/Baseline2_4_No_select_Hart6_UCB_0.1_20_400_6_CumRegret.csv",
    # "./Results/HCA_ini_4_No_select_Hart6_UCB_True_20_400_6_CumRegret.csv",
    # "./Results/COCOA_ini_4_No_select_Hart6_UCB_True_20_400_6_CumRegret.csv",
    # ... 其他文件名
]

# Center_random_2024086_keepinitial_4_Random_select_Hart6_UCB_0.1_20_400_6_Regret.csv

# 定义自定义标签
labels = ['HCA', 'HCA+C','Standard BO', 'Hart6_UCB_Random_select-4-Center', 'Hart6_UCB_Random_select-4-Weight', 'Hart6_Random_AC_No_select']
colors = ['blue', 'red', 'green', 'orange', 'purple','black']

plt.figure(figsize=(4, 3))

# 2. 对每个文件进行迭代
for idx, file in enumerate(filenames_01):
    # 读取数据
    data = pd.read_csv(file, header=None)
    # 计算平均值和标准差
    averages = data.mean(axis=0)
    std_devs = data.std(axis=0)
    
    # 3. 绘制平均值和误差带
    plt.plot(averages, label=labels[idx], color=colors[idx])
    plt.fill_between(range(len(averages)), averages - std_devs, averages + std_devs, color=colors[idx], alpha=0.2)

plt.title("CumRegret")
plt.xlabel("Index")
plt.ylabel("Average Value")
plt.legend()
plt.grid(True)
plt.show()
